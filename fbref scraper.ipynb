# %%
import soccerdata as sd
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
# Out:
# [01/06/25 01:38:33] INFO     No custom team name replacements found. You can configure these in       ]8;id=690466;file://C:\Users\soere\miniconda3\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=540432;file://C:\Users\soere\miniconda3\Lib\site-packages\soccerdata\_config.py#90\90]8;;\
#                              C:\Users\soere\soccerdata\config\teamname_replacements.json.
#                     INFO     Custom league dict loaded from                                          ]8;id=952442;file://C:\Users\soere\miniconda3\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=903501;file://C:\Users\soere\miniconda3\Lib\site-packages\soccerdata\_config.py#194\194]8;;\
#                              C:\Users\soere\soccerdata\config\league_dict.json.

# %%
sd.FBref.available_leagues()
# Out:
# ['Big 5 European Leagues Combined',
#  'ENG-Premier League',
#  'ESP-La Liga',
#  'FRA-Ligue 1',
#  'GER-Bundesliga',
#  'INT-European Championship',
#  "INT-Women's World Cup",
#  'INT-World Cup',
#  'ITA-Serie A']

# %%
fb = sd.FBref(['2. Bundesliga',
 'Allsvenskan',
 'Austrian Bundesliga',
 'Belgian Pro League',
 'Big 5 European Leagues Combined',
 'Brasileiro Série A',
 'Czech League',
 'Danish Superliga',
 'EFL Championship',
 'ENG-Premier League',
 'ESP-La Liga',
 'Eredivisie',
 'FRA-Ligue 1',
 'GER-Bundesliga',
 'ITA-Serie A',
 'J1 Japan',
 'Liga Argentina',
 'Liga Portugal',
 'Ligue 2',
 'MLS',
 'Polish Ekstraklasa',
 'RU Premier League',
 'SUI Super League',
 'Saudi Professional League',
 'Segunda División',
 'Serie B',
 'Süper Lig'],[17,18,19,20,21,22,23])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 fb = sd.FBref(['2. Bundesliga',
#       2  'Allsvenskan',
#       3  'Austrian Bundesliga',
#       4  'Belgian Pro League',
#       5  'Big 5 European Leagues Combined',
#       6  'Brasileiro Série A',
#       7  'Czech League',
#       8  'Danish Superliga',
#       9  'EFL Championship',
#      10  'ENG-Premier League',
#      11  'ESP-La Liga',
#      12  'Eredivisie',
#      13  'FRA-Ligue 1',
#      14  'GER-Bundesliga',
#      15  'ITA-Serie A',
#      16  'J1 Japan',
#      17  'Liga Argentina',
#      18  'Liga Portugal',
#      19  'Ligue 2',
#      20  'MLS',
#      21  'Polish Ekstraklasa',
#      22  'RU Premier League',
#      23  'SUI Super League',
#      24  'Saudi Professional League',
#      25  'Segunda División',
#      26  'Serie B',
# ...

# %%
df = fb.read_player_season_stats()
# Out:
# C:\Users\soere\miniconda3\Lib\site-packages\soccerdata\fbref.py:159: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pd.concat(dfs)
# C:\Users\soere\miniconda3\Lib\site-packages\soccerdata\_common.py:145: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg, stacklevel=1)
# C:\Users\soere\miniconda3\Lib\site-packages\soccerdata\fbref.py:1221: UserWarning: Different columns found for [['INT-World Cup' '2223']] and [['2. Bundesliga' '1718']].
#
# The following columns are missing in [['INT-World Cup' '2223']]: (None, 'Club').
#
# The following columns are missing in [['2. Bundesliga' '1718']]: .
#
# The columns of the dataframe with the most columns will be used.
#   warnings.warn(
# ...

# %%
df
# Out:
#                                                      nation    pos age  Club  \
#
# league        season team         player
# 2. Bundesliga 1718   Arminia      Andraž Šporar         SVN     FW  23  <NA>
#                                   Andreas Voglsammer    GER     FW  25  <NA>
#                                   Brian Behrendt        GER     DF  25  <NA>
#                                   Can Özkan             GER     DF  17  <NA>
#                                   Christoph Hemlein     GER     MF  26  <NA>
# ...                                                     ...    ...  ..   ...
# Süper Lig     2324   İstanbulspor Valon Ethemi          MKD  MF,FW  25  <NA>
#                                   Vefa Temel            FRA  DF,MF  20  <NA>
#                                   Özcan Şahan           FRA     MF  24  <NA>
#                                   İbrahim Yılmaz        TUR     FW  29  <NA>
#                                   İzzet Topatar        <NA>     MF  21  <NA>
#
# ...

# %%
stats = df.reset_index()

# %%
stats.columns = stats.columns.droplevel()

# %%
stats.columns.values[0] = "Liga"
stats.columns.values[1] = "Saison"
stats.columns.values[2] = "Verein"
stats.columns.values[3] = "Spieler"
stats.columns.values[4] = "Nationalität"
stats.columns.values[5] = "Position"
stats.columns.values[6] = "Alter"
stats.columns.values[7] = "Geboren"
stats.columns.values[27] = "Gls p90"
stats.columns.values[28] = "Ast p90"
stats.columns.values[29] = "G+A p90"
stats.columns.values[30] = "G-PK p90"
stats.columns.values[31] = "G+A-PK p90"
stats.columns.values[32] = "xG p90"
stats.columns.values[33] = "xAG p90"
stats.columns.values[34] = "xG+xAG p90"
stats.columns.values[35] = "npxG p90"
stats.columns.values[36] = "npxG+xAG p90"

# %%
stats.columns
# Out:
# Index(['Liga', 'Saison', 'Verein', 'Spieler', 'Nationalität', 'Position',
#        'Alter', 'Geboren', 'born', 'MP', 'Starts', 'Min', '90s', 'Gls', 'Ast',
#        'G+A', 'G-PK', 'PK', 'PKatt', 'CrdY', 'CrdR', 'xG', 'npxG', 'xAG',
#        'npxG+xAG', 'PrgC', 'PrgP', 'Gls p90', 'Ast p90', 'G+A p90', 'G-PK p90',
#        'G+A-PK p90', 'xG p90', 'xAG p90', 'xG+xAG p90', 'npxG p90',
#        'npxG+xAG p90', 'npxG+xAG'],
#       dtype='object')

# %%
def standardize_season(season):
    return str(season)[:-2]

# %%
standardize_season("1920")
# Out:
# '19'

# %%
stats["Saison"] = stats["Saison"].apply(standardize_season)

# %%
stats
# Out:
#                 Liga Saison   Verein             Spieler Nationalität  \
# 0      2. Bundesliga     17  Arminia       Andraž Šporar          SVN
# 1      2. Bundesliga     17  Arminia  Andreas Voglsammer          GER
# 2      2. Bundesliga     17  Arminia      Brian Behrendt          GER
# 3      2. Bundesliga     17  Arminia           Can Özkan          GER
# 4      2. Bundesliga     17  Arminia   Christoph Hemlein          GER
# ...              ...    ...      ...                 ...          ...
# 73555        Serie B     23  Venezia     Michael Svoboda          AUT
# 73556        Serie B     23  Venezia   Mikael Ellertsson          ISL
# 73557        Serie B     23  Venezia    Nicholas Pierini          ITA
# 73558        Serie B     23  Venezia        Nunzio Lella          ITA
# 73559        Serie B     23  Venezia     Tanner Tessmann          USA
#
#       Position  Alter  Geboren  MP  Starts  ...  Gls p90  Ast p90  G+A p90  \
# ...

# %%
stats.to_csv("C:\\Users\\soere\\Bachelorarbeit\\datasets\\raw_data\\player_stats.csv",index=False)
